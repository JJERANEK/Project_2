# %%
# Dependencies
import requests
from pprint import pprint
from config import api_key

url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

# %%
# Search for articles that mention business name
query = "Tesla"
begin_date = "20221101"
end_date = "20221130"
fq = "Financial"

# %%
# Build query URL
query_url = url  + "begin_date=" + begin_date + "&end_date=" + end_date + "&fq=" + fq + "&q=" + query + "&sort=newest&api-key=" + api_key

# %%
# Request articles
articles = requests.get(query_url).json()

# The "response" property in articles contains the actual articles
# list comprehension.
articles_list = articles["response"]["docs"]
pprint(articles_list)
# Out:
# [{'_id': 'nyt://article/07bd79d9-c215-58c2-a07c-b423b6d1cd5d',
#   'abstract': 'Growing protests in the world’s biggest manufacturing nation '
#               'add a new element of uncertainty atop the Ukraine war, an '
#               'energy crisis and inflation.',
#   'byline': {'organization': None,
#              'original': 'By Patricia Cohen',
#              'person': [{'firstname': 'Patricia',
#                          'lastname': 'Cohen',
#                          'middlename': None,
#                          'organization': '',
#                          'qualifier': None,
#                          'rank': 1,
#                          'role': 'reported',
#                          'title': None}]},
#   'document_type': 'article',
#   'headline': {'content_kicker': None,
#                'kicker': None,
#                'main': 'Chinese Unrest Over Lockdown Upends Global Economic '
#                        'Outlook',
#                'name': None,
# ...

# %%
# Print the web_url of each stored article
print("Your Reading List")
print("-----------------------------------------------------------")
for article in articles_list:
    print(article["headline"]["main"])
    print(article["abstract"])
    print(article["web_url"])
    print("-----------------------------------------------------------")
# Out:
# Your Reading List
# -----------------------------------------------------------
# Chinese Unrest Over Lockdown Upends Global Economic Outlook
# Growing protests in the world’s biggest manufacturing nation add a new element of uncertainty atop the Ukraine war, an energy crisis and inflation.
# https://www.nytimes.com/2022/11/28/business/economy/china-unrest-global-economy.html
# -----------------------------------------------------------
# China’s Covid Contagion
# Stock markets in Asia and Europe fell on Monday, as did U.S. futures and crude prices, as investors worried about the fallout of social unrest in China.
# https://www.nytimes.com/2022/11/28/business/dealbook/china-zero-covid-protests.html
# -----------------------------------------------------------
# Have the Anticapitalists Reached Harvard Business School?
# Social justice joins discounted cash flows on the syllabus as essential knowledge for aspiring corporate leaders.
# ...

# %%
# https://api.nytimes.com/svc/search/v2/articlesearch.json?begin_date=20221101&end_date=20221130&fq=Financial&q=Tesla&sort=newest&api-key=[YOUR_API_KEY]
# This is the correct link

# %% [markdown]
# For DF, we would want:
# - Headline
# - abstract
# - Web URL
# - Date (pub_date)
# - Lead Paragraph?

# %%
# Assume DF is already here

for index, row in DF():
    name = row['']

# %%
# Try to reframe to API3 - Activity 5 example

# business_names =[]
# articles_list = []
# for query in business_names:
#     articles = requests.get(query_url).json()
#     articles_list.append(articles["response"]["docs"])
